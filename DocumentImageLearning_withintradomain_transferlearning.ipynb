# %%
import joblib
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import tensorflow.compat.v1 as tf
from tensorflow.compat.v1.keras.backend import set_session

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import seaborn as sns
# https://gist.github.com/greydanus/f6eee59eaf1d90fcb3b534a25362cea4
# https://stackoverflow.com/a/14434334
# this function is used to update the plots for each epoch and error
def plt_dynamic(x, vy, ty, ax, colors=['b']):
    ax.plot(x, vy, 'b', label="Validation Loss")
    ax.plot(x, ty, 'r', label="Train Loss")
    plt.legend()
    plt.grid()
    fig.canvas.draw()

# %%
import tensorflow as tf
config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1000, 
                        inter_op_parallelism_threads=1000, 
                        allow_soft_placement=True)
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True
sess = tf.compat.v1.Session(config=config)
set_session(sess)
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
import shutil

#shutil.unpack_archive('/content/drive/MyDrive/Copy of rvl-cdip.tar.gz','/data')
# Out:
# KeyboardInterrupt

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# 'Colab Notebooks'/          FilteredImages.7z   linkgrt2.zip
# 'Copy of rvl-cdip.tar.gz'   Images/

# %%
# !tar xvzf Copy_of_rvl_cdip.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# images/imagesb/b/o/c/boc54f00/
# images/imagesb/b/o/c/boc54f00/0060330911.tif
# images/imagesb/b/o/c/boc29c00/
# images/imagesb/b/o/c/boc29c00/2074802658_2659.tif
# images/imagesb/b/o/c/boc45c00/
# images/imagesb/b/o/c/boc45c00/2081926255_6261.tif
# images/imagesb/b/o/j/
# images/imagesb/b/o/j/boj32d00/
# images/imagesb/b/o/j/boj32d00/2063849830.tif
# images/imagesb/b/o/j/boj53f00/
# images/imagesb/b/o/j/boj53f00/0001227444.tif
# images/imagesb/b/o/j/boj44c00/
# images/imagesb/b/o/j/boj44c00/87065870.tif
# images/imagesb/b/o/j/boj10f00/
# images/imagesb/b/o/j/boj10f00/0000144841.tif
# images/imagesb/b/o/j/boj26c00/
# images/imagesb/b/o/j/boj26c00/2072610913.tif
# images/imagesb/b/o/j/boj25f00/
# images/imagesb/b/o/j/boj25f00/0060081923.tif
# images/imagesb/b/o/j/boj33a00/
# images/imagesb/b/o/j/boj33a00/515277809+-7809.tif
# images/imagesb/b/o/j/boj37c00/
# images/imagesb/b/o/j/boj37c00/2072652642_2653.tif
# ...

# %%
ls
# Out:
# 'Colab Notebooks'/           FilteredImages.7z   linkgrt2.zip
# 'Copy_of_ rvl_cdip.tar.gz'   Images/

# %%
paths=joblib.load("paths")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-c8d9f26ecbf0> in <module>()
# ----> 1 paths=joblib.load("paths")
#
# /usr/local/lib/python3.6/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     575             obj = _unpickle(fobj)
#     576     else:
# --> 577         with open(filename, 'rb') as f:
#     578             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     579                 if isinstance(fobj, str):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'paths'
